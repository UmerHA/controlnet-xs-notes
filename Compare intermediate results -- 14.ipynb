# %% [markdown]
# The images created by diffusers CNXS for **SD2.1** and canny input are clearly not right. They are far too brown.
#
# Let's compare the Heidelberg and diffusers versions on subblock level.
#
# **Edit:** There were 3 errors, which I've fixed:
# - The random noise given was not N(0,1)
# - The time schedule was wrong
# - The group norm sizes were wrong
#
# The intermediate results on level subblock minus 1 look good. In `Compare intermediate results -- 15.ipynb`, I'll look at the intermediate results on subblock level.

# %%
import os
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'  # needed to make torch deterministic

# %%
import torch
from torch.testing import assert_close
from torch import allclose, nn, tensor
torch.set_printoptions(linewidth=200, precision=3, sci_mode=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps'
device_dtype = torch.float16 if device == 'cuda' else torch.float32

# %% [markdown]
# ## Load logs

# %%
from diffusers.umer_debug_logger import UmerDebugLogger
# Out:
# Info: `UmerDebugLogger` created. This is a logging class that will be deleted when the PR to integrate ControlNet-XS is done.

# %%
cloud_cuda = UmerDebugLogger.load_log_objects_from_dir('logs/cloud')
local_cuda = UmerDebugLogger.load_log_objects_from_dir('logs/local_cuda')

print(len(cloud_cuda), len(local_cuda))

for i, (c,l) in enumerate(zip(cloud_cuda, local_cuda)):
    if c.msg!=l.msg: print(f'{i:<3}{c.msg:>20}{l.msg:>20}')
# Out:
# 539 539

# %% [markdown]
# ## Compare intermediate results

# %%
def mae(t1,t2):
    assert t1.shape==t2.shape
    return (t1-t2).abs().mean()

# %%
from functools import partial
from util_inspect import fmt_bool

def compare_intermediate_results(n=None,n_start=0,prec=5, compare_prec=3, ignore_base=False):
    if n is None: n=max(len(cloud_cuda), len(local_cuda))

    print(f'{"":<3} | {"block":<21} | {"name":<20} | {"shape":<20} | {"same names?":<12} | {"same shapes?":<12} | {"same values?":<12} | {"Δ cuda local -> cloud":<20}')
    print(f'{"":<3} | {"":<21} | {"":<20} | {"":<20} | {"":<12} | {"":<12} | {"prec="+str(compare_prec):^12} | {"prec="+str(prec):^20}')

    def calc_total_len(lens): return sum(lens)+3*len(lens)-1
    total_len = calc_total_len((3,20,20,20,12,12,12,20))

    line = partial(
        lambda txt, width: print(txt * (width//len(txt))),
        width=total_len
    )
    
    labels = []
    def add_label(lbs, ctrl=True):
        if not isinstance(lbs, (list, tuple)): lbs = [lbs]
        for l in lbs:
            labels.append(('Base',l))
        for l in lbs: 
            if ctrl: labels.append(('Ctrl',l))

    # # prep
    labels.append(('Prep','Prep'))
    # # conv_in
    add_label('ConvIn')
    # # down
    # 1
    add_label(('ResBlock d1.1', 'AttnBlock d1.1'))
    add_label(('ResBlock d1.1', 'AttnBlock d1.1'))    
    add_label('Conv d1')
    # 2
    add_label(('ResBlock d2.1', 'AttnBlock d2.1'))
    add_label(('ResBlock d2.2', 'AttnBlock d2.2'))
    add_label('Conv d2')
    # 3
    add_label(('ResBlock d3.1', 'AttnBlock d3.1'))
    add_label(('ResBlock d3.2', 'AttnBlock d3.2')) 
    # # mid
    add_label(('ResBlock m1', 'AttnBlock m', 'ResBlock mid2'))
    # # up
    for _ in range(1000): add_label('DONT CARE', ctrl=False)
    
    line('#')
    bc,block=labels.pop(0)
    for i in range(n_start,n):
        cc,lc = cloud_cuda[i], local_cuda[i]
                
        eq_name = cc.msg==lc.msg
        eq_shape = cc.shape==lc.shape

        if eq_shape:
            eq_vals = torch.allclose(cc.t,lc.t,atol=10**-compare_prec)
            mae_2 = mae(lc.t,cc.t) 
            mae_2 = ("{:>20."+str(prec)+"f}").format(mae_2)
        else:
            eq_vals,mae_2=False,'inf'
        
        if not (ignore_base and bc=='Base'):
            print(f'{i+1:<3} | {bc:<4} | {block:<14} | {cc.msg:<20} | {cc.shape:>20} | {fmt_bool(eq_name, "^12")} | {fmt_bool(eq_shape, "^12")} | {fmt_bool(eq_vals, "^12")} | {mae_2}')

        if cc.msg in ('conv_in.output', 'prep.guided_hint', 'add conv_shortcut','conv','proj_out'):
            line('=')
            bc,block=labels.pop(0)
        elif cc.msg in ('add ff','proj_in'): line('- ')

# %%
compare_intermediate_results(compare_prec=3, prec=3, ignore_base=False)
# Out:
#     | block                 | name                 | shape                | same names?  | same shapes? | same values? | Δ cuda local -> cloud
#     |                       |                      |                      |              |              |    prec=3    |        prec=3
# ##############################################################################################################################################
# 1   | Prep | Prep           | prep.x               |       [2, 4, 64, 64] |      y       |      y       |      y       |                0.000
# 2   | Prep | Prep           | prep.temb            |            [2, 1280] |      y       |      y       |      y       |                0.000
# 3   | Prep | Prep           | prep.context         |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 4   | Prep | Prep           | prep.raw_hint        |     [2, 3, 512, 512] |      y       |      y       |      y       |                0.000
# 5   | Prep | Prep           | prep.guided_hint     |       [2, 4, 64, 64] |      y       |      y       |      y       |                0.000
# ==============================================================================================================================================
# 6   | Base | ConvIn         | conv_in.output       |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.002
# ==============================================================================================================================================
# 7   | Ctrl | ConvIn         | conv_in.output       |       [2, 4, 64, 64] |      y       |      y       |      y       |                0.000
# ==============================================================================================================================================
# 8   | Base | ResBlock d1.1  | input                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.002
# 9   | Base | ResBlock d1.1  | norm1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.002
# 10  | Base | ResBlock d1.1  | conv1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.005
# 11  | Base | ResBlock d1.1  | add time_emb_proj    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.005
# 12  | Base | ResBlock d1.1  | norm2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.002
# 13  | Base | ResBlock d1.1  | conv2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.004
# 14  | Base | ResBlock d1.1  | add conv_shortcut    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.005
# ==============================================================================================================================================
# 15  | Base | AttnBlock d1.1 | norm                 |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.002
# 16  | Base | AttnBlock d1.1 | proj_in              |       [2, 4096, 320] |      y       |      y       |      n       |                0.003
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 17  | Base | AttnBlock d1.1 | norm1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.007
# 18  | Base | AttnBlock d1.1 | attn1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.005
# 19  | Base | AttnBlock d1.1 | add attn1            |       [2, 4096, 320] |      y       |      y       |      n       |                0.005
# 20  | Base | AttnBlock d1.1 | norm2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.006
# 21  | Base | AttnBlock d1.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 22  | Base | AttnBlock d1.1 | attn2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.001
# 23  | Base | AttnBlock d1.1 | add attn2            |       [2, 4096, 320] |      y       |      y       |      n       |                0.006
# 24  | Base | AttnBlock d1.1 | norm3                |       [2, 4096, 320] |      y       |      y       |      n       |                0.008
# 25  | Base | AttnBlock d1.1 | ff                   |       [2, 4096, 320] |      y       |      y       |      n       |                0.007
# 26  | Base | AttnBlock d1.1 | add ff               |       [2, 4096, 320] |      y       |      y       |      n       |                0.008
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 27  | Base | AttnBlock d1.1 | proj_out             |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.009
# ==============================================================================================================================================
# 28  | Ctrl | ResBlock d1.1  | input                |     [2, 324, 64, 64] |      y       |      y       |      n       |                0.010
# 29  | Ctrl | ResBlock d1.1  | norm1                |     [2, 324, 64, 64] |      y       |      y       |      n       |                0.011
# 30  | Ctrl | ResBlock d1.1  | conv1                |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.020
# 31  | Ctrl | ResBlock d1.1  | add time_emb_proj    |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.020
# 32  | Ctrl | ResBlock d1.1  | norm2                |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.012
# 33  | Ctrl | ResBlock d1.1  | conv2                |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.012
# 34  | Ctrl | ResBlock d1.1  | add conv_shortcut    |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.080
# ==============================================================================================================================================
# 35  | Ctrl | AttnBlock d1.1 | norm                 |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.006
# 36  | Ctrl | AttnBlock d1.1 | proj_in              |         [2, 4096, 4] |      y       |      y       |      n       |                0.004
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 37  | Ctrl | AttnBlock d1.1 | norm1                |         [2, 4096, 4] |      y       |      y       |      n       |                0.009
# 38  | Ctrl | AttnBlock d1.1 | attn1                |         [2, 4096, 4] |      y       |      y       |      n       |                0.001
# 39  | Ctrl | AttnBlock d1.1 | add attn1            |         [2, 4096, 4] |      y       |      y       |      n       |                0.005
# 40  | Ctrl | AttnBlock d1.1 | norm2                |         [2, 4096, 4] |      y       |      y       |      n       |                0.009
# 41  | Ctrl | AttnBlock d1.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 42  | Ctrl | AttnBlock d1.1 | attn2                |         [2, 4096, 4] |      y       |      y       |      n       |                0.009
# 43  | Ctrl | AttnBlock d1.1 | add attn2            |         [2, 4096, 4] |      y       |      y       |      n       |                0.011
# 44  | Ctrl | AttnBlock d1.1 | norm3                |         [2, 4096, 4] |      y       |      y       |      n       |                0.008
# 45  | Ctrl | AttnBlock d1.1 | ff                   |         [2, 4096, 4] |      y       |      y       |      n       |                0.004
# 46  | Ctrl | AttnBlock d1.1 | add ff               |         [2, 4096, 4] |      y       |      y       |      n       |                0.012
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 47  | Ctrl | AttnBlock d1.1 | proj_out             |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.080
# ==============================================================================================================================================
# 48  | Base | ResBlock d1.1  | input                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.014
# 49  | Base | ResBlock d1.1  | norm1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.007
# 50  | Base | ResBlock d1.1  | conv1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.013
# 51  | Base | ResBlock d1.1  | add time_emb_proj    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.013
# 52  | Base | ResBlock d1.1  | norm2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.010
# 53  | Base | ResBlock d1.1  | conv2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.010
# 54  | Base | ResBlock d1.1  | add conv_shortcut    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.016
# ==============================================================================================================================================
# 55  | Base | AttnBlock d1.1 | norm                 |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.008
# 56  | Base | AttnBlock d1.1 | proj_in              |       [2, 4096, 320] |      y       |      y       |      n       |                0.009
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 57  | Base | AttnBlock d1.1 | norm1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.016
# 58  | Base | AttnBlock d1.1 | attn1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.008
# 59  | Base | AttnBlock d1.1 | add attn1            |       [2, 4096, 320] |      y       |      y       |      n       |                0.010
# 60  | Base | AttnBlock d1.1 | norm2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.005
# 61  | Base | AttnBlock d1.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 62  | Base | AttnBlock d1.1 | attn2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.002
# 63  | Base | AttnBlock d1.1 | add attn2            |       [2, 4096, 320] |      y       |      y       |      n       |                0.011
# 64  | Base | AttnBlock d1.1 | norm3                |       [2, 4096, 320] |      y       |      y       |      n       |                0.010
# 65  | Base | AttnBlock d1.1 | ff                   |       [2, 4096, 320] |      y       |      y       |      n       |                0.008
# 66  | Base | AttnBlock d1.1 | add ff               |       [2, 4096, 320] |      y       |      y       |      n       |                0.012
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 67  | Base | AttnBlock d1.1 | proj_out             |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.017
# ==============================================================================================================================================
# 68  | Ctrl | ResBlock d1.1  | input                |     [2, 324, 64, 64] |      y       |      y       |      n       |                0.027
# 69  | Ctrl | ResBlock d1.1  | norm1                |     [2, 324, 64, 64] |      y       |      y       |      n       |                0.025
# 70  | Ctrl | ResBlock d1.1  | conv1                |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.046
# 71  | Ctrl | ResBlock d1.1  | add time_emb_proj    |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.046
# 72  | Ctrl | ResBlock d1.1  | norm2                |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.048
# 73  | Ctrl | ResBlock d1.1  | conv2                |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.090
# 74  | Ctrl | ResBlock d1.1  | add conv_shortcut    |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.171
# ==============================================================================================================================================
# 75  | Ctrl | AttnBlock d1.1 | norm                 |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.016
# 76  | Ctrl | AttnBlock d1.1 | proj_in              |         [2, 4096, 4] |      y       |      y       |      n       |                0.008
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 77  | Ctrl | AttnBlock d1.1 | norm1                |         [2, 4096, 4] |      y       |      y       |      n       |                0.017
# 78  | Ctrl | AttnBlock d1.1 | attn1                |         [2, 4096, 4] |      y       |      y       |      n       |                0.001
# 79  | Ctrl | AttnBlock d1.1 | add attn1            |         [2, 4096, 4] |      y       |      y       |      n       |                0.009
# 80  | Ctrl | AttnBlock d1.1 | norm2                |         [2, 4096, 4] |      y       |      y       |      n       |                0.014
# 81  | Ctrl | AttnBlock d1.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 82  | Ctrl | AttnBlock d1.1 | attn2                |         [2, 4096, 4] |      y       |      y       |      n       |                0.048
# 83  | Ctrl | AttnBlock d1.1 | add attn2            |         [2, 4096, 4] |      y       |      y       |      n       |                0.050
# 84  | Ctrl | AttnBlock d1.1 | norm3                |         [2, 4096, 4] |      y       |      y       |      n       |                0.026
# 85  | Ctrl | AttnBlock d1.1 | ff                   |         [2, 4096, 4] |      y       |      y       |      n       |                0.017
# 86  | Ctrl | AttnBlock d1.1 | add ff               |         [2, 4096, 4] |      y       |      y       |      n       |                0.055
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 87  | Ctrl | AttnBlock d1.1 | proj_out             |       [2, 4, 64, 64] |      y       |      y       |      n       |                0.171
# ==============================================================================================================================================
# 88  | Base | Conv d1        | conv                 |     [2, 320, 32, 32] |      y       |      y       |      n       |                0.068
# ==============================================================================================================================================
# 89  | Ctrl | Conv d1        | conv                 |       [2, 4, 32, 32] |      y       |      y       |      n       |                0.341
# ==============================================================================================================================================
# 90  | Base | ResBlock d2.1  | input                |     [2, 320, 32, 32] |      y       |      y       |      n       |                0.071
# 91  | Base | ResBlock d2.1  | norm1                |     [2, 320, 32, 32] |      y       |      y       |      n       |                0.011
# 92  | Base | ResBlock d2.1  | conv1                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.024
# 93  | Base | ResBlock d2.1  | add time_emb_proj    |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.024
# 94  | Base | ResBlock d2.1  | norm2                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.013
# 95  | Base | ResBlock d2.1  | conv2                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.023
# 96  | Base | ResBlock d2.1  | add conv_shortcut    |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.044
# ==============================================================================================================================================
# 97  | Base | AttnBlock d2.1 | norm                 |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.012
# 98  | Base | AttnBlock d2.1 | proj_in              |       [2, 1024, 640] |      y       |      y       |      n       |                0.019
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 99  | Base | AttnBlock d2.1 | norm1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.016
# 100 | Base | AttnBlock d2.1 | attn1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.020
# 101 | Base | AttnBlock d2.1 | add attn1            |       [2, 1024, 640] |      y       |      y       |      n       |                0.025
# 102 | Base | AttnBlock d2.1 | norm2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.013
# 103 | Base | AttnBlock d2.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 104 | Base | AttnBlock d2.1 | attn2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.005
# 105 | Base | AttnBlock d2.1 | add attn2            |       [2, 1024, 640] |      y       |      y       |      n       |                0.026
# 106 | Base | AttnBlock d2.1 | norm3                |       [2, 1024, 640] |      y       |      y       |      n       |                0.013
# 107 | Base | AttnBlock d2.1 | ff                   |       [2, 1024, 640] |      y       |      y       |      n       |                0.028
# 108 | Base | AttnBlock d2.1 | add ff               |       [2, 1024, 640] |      y       |      y       |      n       |                0.036
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 109 | Base | AttnBlock d2.1 | proj_out             |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.054
# ==============================================================================================================================================
# 110 | Ctrl | ResBlock d2.1  | input                |     [2, 324, 32, 32] |      y       |      y       |      n       |                0.118
# 111 | Ctrl | ResBlock d2.1  | norm1                |     [2, 324, 32, 32] |      y       |      y       |      n       |                0.028
# 112 | Ctrl | ResBlock d2.1  | conv1                |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.053
# 113 | Ctrl | ResBlock d2.1  | add time_emb_proj    |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.053
# 114 | Ctrl | ResBlock d2.1  | norm2                |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.062
# 115 | Ctrl | ResBlock d2.1  | conv2                |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.116
# 116 | Ctrl | ResBlock d2.1  | add conv_shortcut    |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.215
# ==============================================================================================================================================
# 117 | Ctrl | AttnBlock d2.1 | norm                 |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.034
# 118 | Ctrl | AttnBlock d2.1 | proj_in              |         [2, 1024, 8] |      y       |      y       |      n       |                0.017
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 119 | Ctrl | AttnBlock d2.1 | norm1                |         [2, 1024, 8] |      y       |      y       |      n       |                0.030
# 120 | Ctrl | AttnBlock d2.1 | attn1                |         [2, 1024, 8] |      y       |      y       |      n       |                0.008
# 121 | Ctrl | AttnBlock d2.1 | add attn1            |         [2, 1024, 8] |      y       |      y       |      n       |                0.019
# 122 | Ctrl | AttnBlock d2.1 | norm2                |         [2, 1024, 8] |      y       |      y       |      n       |                0.018
# 123 | Ctrl | AttnBlock d2.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 124 | Ctrl | AttnBlock d2.1 | attn2                |         [2, 1024, 8] |      y       |      y       |      n       |                0.132
# 125 | Ctrl | AttnBlock d2.1 | add attn2            |         [2, 1024, 8] |      y       |      y       |      n       |                0.136
# 126 | Ctrl | AttnBlock d2.1 | norm3                |         [2, 1024, 8] |      y       |      y       |      n       |                0.026
# 127 | Ctrl | AttnBlock d2.1 | ff                   |         [2, 1024, 8] |      y       |      y       |      n       |                0.059
# 128 | Ctrl | AttnBlock d2.1 | add ff               |         [2, 1024, 8] |      y       |      y       |      n       |                0.178
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 129 | Ctrl | AttnBlock d2.1 | proj_out             |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.239
# ==============================================================================================================================================
# 130 | Base | ResBlock d2.2  | input                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.069
# 131 | Base | ResBlock d2.2  | norm1                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.012
# 132 | Base | ResBlock d2.2  | conv1                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.036
# 133 | Base | ResBlock d2.2  | add time_emb_proj    |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.036
# 134 | Base | ResBlock d2.2  | norm2                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.027
# 135 | Base | ResBlock d2.2  | conv2                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.045
# 136 | Base | ResBlock d2.2  | add conv_shortcut    |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.076
# ==============================================================================================================================================
# 137 | Base | AttnBlock d2.2 | norm                 |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.021
# 138 | Base | AttnBlock d2.2 | proj_in              |       [2, 1024, 640] |      y       |      y       |      n       |                0.037
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 139 | Base | AttnBlock d2.2 | norm1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.022
# 140 | Base | AttnBlock d2.2 | attn1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.024
# 141 | Base | AttnBlock d2.2 | add attn1            |       [2, 1024, 640] |      y       |      y       |      n       |                0.041
# 142 | Base | AttnBlock d2.2 | norm2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.017
# 143 | Base | AttnBlock d2.2 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 144 | Base | AttnBlock d2.2 | attn2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.004
# 145 | Base | AttnBlock d2.2 | add attn2            |       [2, 1024, 640] |      y       |      y       |      n       |                0.041
# 146 | Base | AttnBlock d2.2 | norm3                |       [2, 1024, 640] |      y       |      y       |      n       |                0.015
# 147 | Base | AttnBlock d2.2 | ff                   |       [2, 1024, 640] |      y       |      y       |      n       |                0.033
# 148 | Base | AttnBlock d2.2 | add ff               |       [2, 1024, 640] |      y       |      y       |      n       |                0.049
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 149 | Base | AttnBlock d2.2 | proj_out             |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.070
# ==============================================================================================================================================
# 150 | Ctrl | ResBlock d2.2  | input                |     [2, 648, 32, 32] |      y       |      y       |      n       |                0.131
# 151 | Ctrl | ResBlock d2.2  | norm1                |     [2, 648, 32, 32] |      y       |      y       |      n       |                0.038
# 152 | Ctrl | ResBlock d2.2  | conv1                |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.107
# 153 | Ctrl | ResBlock d2.2  | add time_emb_proj    |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.107
# 154 | Ctrl | ResBlock d2.2  | norm2                |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.124
# 155 | Ctrl | ResBlock d2.2  | conv2                |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.273
# 156 | Ctrl | ResBlock d2.2  | add conv_shortcut    |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.372
# ==============================================================================================================================================
# 157 | Ctrl | AttnBlock d2.2 | norm                 |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.065
# 158 | Ctrl | AttnBlock d2.2 | proj_in              |         [2, 1024, 8] |      y       |      y       |      n       |                0.036
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 159 | Ctrl | AttnBlock d2.2 | norm1                |         [2, 1024, 8] |      y       |      y       |      n       |                0.059
# 160 | Ctrl | AttnBlock d2.2 | attn1                |         [2, 1024, 8] |      y       |      y       |      n       |                0.023
# 161 | Ctrl | AttnBlock d2.2 | add attn1            |         [2, 1024, 8] |      y       |      y       |      n       |                0.047
# 162 | Ctrl | AttnBlock d2.2 | norm2                |         [2, 1024, 8] |      y       |      y       |      n       |                0.042
# 163 | Ctrl | AttnBlock d2.2 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 164 | Ctrl | AttnBlock d2.2 | attn2                |         [2, 1024, 8] |      y       |      y       |      n       |                0.134
# 165 | Ctrl | AttnBlock d2.2 | add attn2            |         [2, 1024, 8] |      y       |      y       |      n       |                0.165
# 166 | Ctrl | AttnBlock d2.2 | norm3                |         [2, 1024, 8] |      y       |      y       |      n       |                0.071
# 167 | Ctrl | AttnBlock d2.2 | ff                   |         [2, 1024, 8] |      y       |      y       |      n       |                0.156
# 168 | Ctrl | AttnBlock d2.2 | add ff               |         [2, 1024, 8] |      y       |      y       |      n       |                0.273
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 169 | Ctrl | AttnBlock d2.2 | proj_out             |       [2, 8, 32, 32] |      y       |      y       |      n       |                0.398
# ==============================================================================================================================================
# 170 | Base | Conv d2        | conv                 |     [2, 640, 16, 16] |      y       |      y       |      n       |                0.190
# ==============================================================================================================================================
# 171 | Ctrl | Conv d2        | conv                 |       [2, 8, 16, 16] |      y       |      y       |      n       |                0.703
# ==============================================================================================================================================
# 172 | Base | ResBlock d3.1  | input                |     [2, 640, 16, 16] |      y       |      y       |      n       |                0.202
# 173 | Base | ResBlock d3.1  | norm1                |     [2, 640, 16, 16] |      y       |      y       |      n       |                0.025
# 174 | Base | ResBlock d3.1  | conv1                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.067
# 175 | Base | ResBlock d3.1  | add time_emb_proj    |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.067
# 176 | Base | ResBlock d3.1  | norm2                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.030
# 177 | Base | ResBlock d3.1  | conv2                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.079
# 178 | Base | ResBlock d3.1  | add conv_shortcut    |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.128
# ==============================================================================================================================================
# 179 | Base | AttnBlock d3.1 | norm                 |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.017
# 180 | Base | AttnBlock d3.1 | proj_in              |       [2, 256, 1280] |      y       |      y       |      n       |                0.048
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 181 | Base | AttnBlock d3.1 | norm1                |       [2, 256, 1280] |      y       |      y       |      n       |                0.015
# 182 | Base | AttnBlock d3.1 | attn1                |       [2, 256, 1280] |      y       |      y       |      n       |                0.038
# 183 | Base | AttnBlock d3.1 | add attn1            |       [2, 256, 1280] |      y       |      y       |      n       |                0.057
# 184 | Base | AttnBlock d3.1 | norm2                |       [2, 256, 1280] |      y       |      y       |      n       |                0.014
# 185 | Base | AttnBlock d3.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 186 | Base | AttnBlock d3.1 | attn2                |       [2, 256, 1280] |      y       |      y       |      n       |                0.016
# 187 | Base | AttnBlock d3.1 | add attn2            |       [2, 256, 1280] |      y       |      y       |      n       |                0.059
# 188 | Base | AttnBlock d3.1 | norm3                |       [2, 256, 1280] |      y       |      y       |      n       |                0.018
# 189 | Base | AttnBlock d3.1 | ff                   |       [2, 256, 1280] |      y       |      y       |      n       |                0.059
# 190 | Base | AttnBlock d3.1 | add ff               |       [2, 256, 1280] |      y       |      y       |      n       |                0.078
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 191 | Base | AttnBlock d3.1 | proj_out             |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.138
# ==============================================================================================================================================
# 192 | Ctrl | ResBlock d3.1  | input                |     [2, 648, 16, 16] |      y       |      y       |      n       |                0.240
# 193 | Ctrl | ResBlock d3.1  | norm1                |     [2, 648, 16, 16] |      y       |      y       |      n       |                0.061
# 194 | Ctrl | ResBlock d3.1  | conv1                |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.512
# 195 | Ctrl | ResBlock d3.1  | add time_emb_proj    |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.512
# 196 | Ctrl | ResBlock d3.1  | norm2                |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.041
# 197 | Ctrl | ResBlock d3.1  | conv2                |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.032
# 198 | Ctrl | ResBlock d3.1  | add conv_shortcut    |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.353
# ==============================================================================================================================================
# 199 | Ctrl | AttnBlock d3.1 | norm                 |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.064
# 200 | Ctrl | AttnBlock d3.1 | proj_in              |         [2, 256, 16] |      y       |      y       |      n       |                0.045
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 201 | Ctrl | AttnBlock d3.1 | norm1                |         [2, 256, 16] |      y       |      y       |      n       |                0.054
# 202 | Ctrl | AttnBlock d3.1 | attn1                |         [2, 256, 16] |      y       |      y       |      n       |                0.011
# 203 | Ctrl | AttnBlock d3.1 | add attn1            |         [2, 256, 16] |      y       |      y       |      n       |                0.050
# 204 | Ctrl | AttnBlock d3.1 | norm2                |         [2, 256, 16] |      y       |      y       |      n       |                0.050
# 205 | Ctrl | AttnBlock d3.1 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 206 | Ctrl | AttnBlock d3.1 | attn2                |         [2, 256, 16] |      y       |      y       |      n       |                0.097
# 207 | Ctrl | AttnBlock d3.1 | add attn2            |         [2, 256, 16] |      y       |      y       |      n       |                0.127
# 208 | Ctrl | AttnBlock d3.1 | norm3                |         [2, 256, 16] |      y       |      y       |      n       |                0.063
# 209 | Ctrl | AttnBlock d3.1 | ff                   |         [2, 256, 16] |      y       |      y       |      n       |                0.036
# 210 | Ctrl | AttnBlock d3.1 | add ff               |         [2, 256, 16] |      y       |      y       |      n       |                0.147
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 211 | Ctrl | AttnBlock d3.1 | proj_out             |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.343
# ==============================================================================================================================================
# 212 | Base | ResBlock d3.2  | input                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.150
# 213 | Base | ResBlock d3.2  | norm1                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.027
# 214 | Base | ResBlock d3.2  | conv1                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.085
# 215 | Base | ResBlock d3.2  | add time_emb_proj    |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.085
# 216 | Base | ResBlock d3.2  | norm2                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.036
# 217 | Base | ResBlock d3.2  | conv2                |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.082
# 218 | Base | ResBlock d3.2  | add conv_shortcut    |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.158
# ==============================================================================================================================================
# 219 | Base | AttnBlock d3.2 | norm                 |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.023
# 220 | Base | AttnBlock d3.2 | proj_in              |       [2, 256, 1280] |      y       |      y       |      n       |                0.059
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 221 | Base | AttnBlock d3.2 | norm1                |       [2, 256, 1280] |      y       |      y       |      n       |                0.018
# 222 | Base | AttnBlock d3.2 | attn1                |       [2, 256, 1280] |      y       |      y       |      n       |                0.041
# 223 | Base | AttnBlock d3.2 | add attn1            |       [2, 256, 1280] |      y       |      y       |      n       |                0.068
# 224 | Base | AttnBlock d3.2 | norm2                |       [2, 256, 1280] |      y       |      y       |      n       |                0.023
# 225 | Base | AttnBlock d3.2 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 226 | Base | AttnBlock d3.2 | attn2                |       [2, 256, 1280] |      y       |      y       |      n       |                0.015
# 227 | Base | AttnBlock d3.2 | add attn2            |       [2, 256, 1280] |      y       |      y       |      n       |                0.070
# 228 | Base | AttnBlock d3.2 | norm3                |       [2, 256, 1280] |      y       |      y       |      n       |                0.022
# 229 | Base | AttnBlock d3.2 | ff                   |       [2, 256, 1280] |      y       |      y       |      n       |                0.071
# 230 | Base | AttnBlock d3.2 | add ff               |       [2, 256, 1280] |      y       |      y       |      n       |                0.094
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 231 | Base | AttnBlock d3.2 | proj_out             |    [2, 1280, 16, 16] |      y       |      y       |      n       |                0.176
# ==============================================================================================================================================
# 232 | Ctrl | ResBlock d3.2  | input                |    [2, 1296, 16, 16] |      y       |      y       |      n       |                0.287
# 233 | Ctrl | ResBlock d3.2  | norm1                |    [2, 1296, 16, 16] |      y       |      y       |      n       |                0.064
# 234 | Ctrl | ResBlock d3.2  | conv1                |      [2, 16, 16, 16] |      y       |      y       |      n       |                1.000
# 235 | Ctrl | ResBlock d3.2  | add time_emb_proj    |      [2, 16, 16, 16] |      y       |      y       |      n       |                1.000
# 236 | Ctrl | ResBlock d3.2  | norm2                |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.059
# 237 | Ctrl | ResBlock d3.2  | conv2                |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.031
# 238 | Ctrl | ResBlock d3.2  | add conv_shortcut    |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.870
# ==============================================================================================================================================
# 239 | Ctrl | AttnBlock d3.2 | norm                 |      [2, 16, 16, 16] |      y       |      y       |      n       |                0.067
# 240 | Ctrl | AttnBlock d3.2 | proj_in              |         [2, 256, 16] |      y       |      y       |      n       |                0.072
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 241 | Ctrl | AttnBlock d3.2 | norm1                |         [2, 256, 16] |      y       |      y       |      n       |                0.062
# 242 | Ctrl | AttnBlock d3.2 | attn1                |         [2, 256, 16] |      y       |      y       |      n       |                0.018
# 243 | Ctrl | AttnBlock d3.2 | add attn1            |         [2, 256, 16] |      y       |      y       |      n       |                0.085
# 244 | Ctrl | AttnBlock d3.2 | norm2                |         [2, 256, 16] |      y       |      y       |      n       |                0.059
# 245 | Ctrl | AttnBlock d3.2 | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 246 | Ctrl | AttnBlock d3.2 | attn2                |         [2, 256, 16] |      y       |      y       |      n       |                0.337
# 247 | Ctrl | AttnBlock d3.2 | add attn2            |         [2, 256, 16] |      y       |      y       |      n       |                0.399
# 248 | Ctrl | AttnBlock d3.2 | norm3                |         [2, 256, 16] |      y       |      y       |      n       |                0.062
# 249 | Ctrl | AttnBlock d3.2 | ff                   |         [2, 256, 16] |      y       |      y       |      n       |                0.192
# 250 | Ctrl | AttnBlock d3.2 | add ff               |         [2, 256, 16] |      y       |      y       |      n       |                0.554
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 251 | Ctrl | AttnBlock d3.2 | proj_out             |      [2, 16, 16, 16] |      y       |      y       |      n       |                1.030
# ==============================================================================================================================================
# 252 | Base | ResBlock m1    | conv                 |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.413
# ==============================================================================================================================================
# 253 | Base | AttnBlock m    | conv                 |        [2, 16, 8, 8] |      y       |      y       |      n       |                1.689
# ==============================================================================================================================================
# 254 | Base | ResBlock mid2  | input                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.457
# 255 | Base | ResBlock mid2  | norm1                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.036
# 256 | Base | ResBlock mid2  | conv1                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.073
# 257 | Base | ResBlock mid2  | add time_emb_proj    |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.073
# 258 | Base | ResBlock mid2  | norm2                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.067
# 259 | Base | ResBlock mid2  | conv2                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.219
# 260 | Base | ResBlock mid2  | add conv_shortcut    |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.464
# ==============================================================================================================================================
# 261 | Ctrl | ResBlock m1    | input                |      [2, 1296, 8, 8] |      y       |      y       |      n       |                0.423
# 262 | Ctrl | ResBlock m1    | norm1                |      [2, 1296, 8, 8] |      y       |      y       |      n       |                0.086
# 263 | Ctrl | ResBlock m1    | conv1                |        [2, 16, 8, 8] |      y       |      y       |      n       |                0.514
# 264 | Ctrl | ResBlock m1    | add time_emb_proj    |        [2, 16, 8, 8] |      y       |      y       |      n       |                0.514
# 265 | Ctrl | ResBlock m1    | norm2                |        [2, 16, 8, 8] |      y       |      y       |      n       |                0.057
# 266 | Ctrl | ResBlock m1    | conv2                |        [2, 16, 8, 8] |      y       |      y       |      n       |                0.043
# 267 | Ctrl | ResBlock m1    | add conv_shortcut    |        [2, 16, 8, 8] |      y       |      y       |      n       |                0.590
# ==============================================================================================================================================
# 268 | Ctrl | AttnBlock m    | input                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.471
# 269 | Ctrl | AttnBlock m    | norm1                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.031
# 270 | Ctrl | AttnBlock m    | conv1                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.046
# 271 | Ctrl | AttnBlock m    | add time_emb_proj    |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.046
# 272 | Ctrl | AttnBlock m    | norm2                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.054
# 273 | Ctrl | AttnBlock m    | conv2                |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.148
# 274 | Ctrl | AttnBlock m    | add conv_shortcut    |      [2, 1280, 8, 8] |      y       |      y       |      n       |                0.477
# ==============================================================================================================================================
# ...
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 448 | Base | DONT CARE      | norm1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.032
# 449 | Base | DONT CARE      | attn1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.041
# 450 | Base | DONT CARE      | add attn1            |       [2, 1024, 640] |      y       |      y       |      n       |                0.063
# 451 | Base | DONT CARE      | norm2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.028
# 452 | Base | DONT CARE      | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 453 | Base | DONT CARE      | attn2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.005
# 454 | Base | DONT CARE      | add attn2            |       [2, 1024, 640] |      y       |      y       |      n       |                0.063
# 455 | Base | DONT CARE      | norm3                |       [2, 1024, 640] |      y       |      y       |      n       |                0.027
# 456 | Base | DONT CARE      | ff                   |       [2, 1024, 640] |      y       |      y       |      n       |                0.063
# 457 | Base | DONT CARE      | add ff               |       [2, 1024, 640] |      y       |      y       |      n       |                0.085
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 458 | Base | DONT CARE      | proj_out             |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.196
# ==============================================================================================================================================
# 459 | Base | DONT CARE      | input                |     [2, 960, 32, 32] |      y       |      y       |      n       |                0.165
# 460 | Base | DONT CARE      | norm1                |     [2, 960, 32, 32] |      y       |      y       |      n       |                0.010
# 461 | Base | DONT CARE      | conv1                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.031
# 462 | Base | DONT CARE      | add time_emb_proj    |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.031
# 463 | Base | DONT CARE      | norm2                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.032
# 464 | Base | DONT CARE      | conv2                |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.054
# 465 | Base | DONT CARE      | add conv_shortcut    |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.112
# ==============================================================================================================================================
# 466 | Base | DONT CARE      | norm                 |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.027
# 467 | Base | DONT CARE      | proj_in              |       [2, 1024, 640] |      y       |      y       |      n       |                0.046
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 468 | Base | DONT CARE      | norm1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.029
# 469 | Base | DONT CARE      | attn1                |       [2, 1024, 640] |      y       |      y       |      n       |                0.033
# 470 | Base | DONT CARE      | add attn1            |       [2, 1024, 640] |      y       |      y       |      n       |                0.053
# 471 | Base | DONT CARE      | norm2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.027
# 472 | Base | DONT CARE      | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 473 | Base | DONT CARE      | attn2                |       [2, 1024, 640] |      y       |      y       |      n       |                0.008
# 474 | Base | DONT CARE      | add attn2            |       [2, 1024, 640] |      y       |      y       |      n       |                0.054
# 475 | Base | DONT CARE      | norm3                |       [2, 1024, 640] |      y       |      y       |      n       |                0.022
# 476 | Base | DONT CARE      | ff                   |       [2, 1024, 640] |      y       |      y       |      n       |                0.037
# 477 | Base | DONT CARE      | add ff               |       [2, 1024, 640] |      y       |      y       |      n       |                0.062
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 478 | Base | DONT CARE      | proj_out             |     [2, 640, 32, 32] |      y       |      y       |      n       |                0.085
# ==============================================================================================================================================
# 479 | Base | DONT CARE      | conv                 |     [2, 640, 64, 64] |      y       |      y       |      n       |                0.211
# ==============================================================================================================================================
# 480 | Base | DONT CARE      | input                |     [2, 960, 64, 64] |      y       |      y       |      n       |                0.169
# 481 | Base | DONT CARE      | norm1                |     [2, 960, 64, 64] |      y       |      y       |      n       |                0.023
# 482 | Base | DONT CARE      | conv1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.046
# 483 | Base | DONT CARE      | add time_emb_proj    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.046
# 484 | Base | DONT CARE      | norm2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.030
# 485 | Base | DONT CARE      | conv2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.042
# 486 | Base | DONT CARE      | add conv_shortcut    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.091
# ==============================================================================================================================================
# 487 | Base | DONT CARE      | norm                 |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.024
# 488 | Base | DONT CARE      | proj_in              |       [2, 4096, 320] |      y       |      y       |      n       |                0.024
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 489 | Base | DONT CARE      | norm1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.038
# 490 | Base | DONT CARE      | attn1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.021
# 491 | Base | DONT CARE      | add attn1            |       [2, 4096, 320] |      y       |      y       |      n       |                0.027
# 492 | Base | DONT CARE      | norm2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.014
# 493 | Base | DONT CARE      | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 494 | Base | DONT CARE      | attn2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.004
# 495 | Base | DONT CARE      | add attn2            |       [2, 4096, 320] |      y       |      y       |      n       |                0.028
# 496 | Base | DONT CARE      | norm3                |       [2, 4096, 320] |      y       |      y       |      n       |                0.032
# 497 | Base | DONT CARE      | ff                   |       [2, 4096, 320] |      y       |      y       |      n       |                0.041
# 498 | Base | DONT CARE      | add ff               |       [2, 4096, 320] |      y       |      y       |      n       |                0.050
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 499 | Base | DONT CARE      | proj_out             |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.112
# ==============================================================================================================================================
# 500 | Base | DONT CARE      | input                |     [2, 640, 64, 64] |      y       |      y       |      n       |                0.068
# 501 | Base | DONT CARE      | norm1                |     [2, 640, 64, 64] |      y       |      y       |      n       |                0.008
# 502 | Base | DONT CARE      | conv1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.023
# 503 | Base | DONT CARE      | add time_emb_proj    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.023
# 504 | Base | DONT CARE      | norm2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.018
# 505 | Base | DONT CARE      | conv2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.024
# 506 | Base | DONT CARE      | add conv_shortcut    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.045
# ==============================================================================================================================================
# 507 | Base | DONT CARE      | norm                 |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.018
# 508 | Base | DONT CARE      | proj_in              |       [2, 4096, 320] |      y       |      y       |      n       |                0.019
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 509 | Base | DONT CARE      | norm1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.025
# 510 | Base | DONT CARE      | attn1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.018
# 511 | Base | DONT CARE      | add attn1            |       [2, 4096, 320] |      y       |      y       |      n       |                0.022
# 512 | Base | DONT CARE      | norm2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.011
# 513 | Base | DONT CARE      | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 514 | Base | DONT CARE      | attn2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.003
# 515 | Base | DONT CARE      | add attn2            |       [2, 4096, 320] |      y       |      y       |      n       |                0.023
# 516 | Base | DONT CARE      | norm3                |       [2, 4096, 320] |      y       |      y       |      n       |                0.025
# 517 | Base | DONT CARE      | ff                   |       [2, 4096, 320] |      y       |      y       |      n       |                0.024
# 518 | Base | DONT CARE      | add ff               |       [2, 4096, 320] |      y       |      y       |      n       |                0.032
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 519 | Base | DONT CARE      | proj_out             |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.055
# ==============================================================================================================================================
# 520 | Base | DONT CARE      | input                |     [2, 640, 64, 64] |      y       |      y       |      n       |                0.029
# 521 | Base | DONT CARE      | norm1                |     [2, 640, 64, 64] |      y       |      y       |      n       |                0.005
# 522 | Base | DONT CARE      | conv1                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.020
# 523 | Base | DONT CARE      | add time_emb_proj    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.020
# 524 | Base | DONT CARE      | norm2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.011
# 525 | Base | DONT CARE      | conv2                |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.019
# 526 | Base | DONT CARE      | add conv_shortcut    |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.033
# ==============================================================================================================================================
# 527 | Base | DONT CARE      | norm                 |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.007
# 528 | Base | DONT CARE      | proj_in              |       [2, 4096, 320] |      y       |      y       |      n       |                0.008
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 529 | Base | DONT CARE      | norm1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.018
# 530 | Base | DONT CARE      | attn1                |       [2, 4096, 320] |      y       |      y       |      n       |                0.008
# 531 | Base | DONT CARE      | add attn1            |       [2, 4096, 320] |      y       |      y       |      n       |                0.010
# 532 | Base | DONT CARE      | norm2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.006
# 533 | Base | DONT CARE      | context              |        [2, 77, 1024] |      y       |      y       |      y       |                0.000
# 534 | Base | DONT CARE      | attn2                |       [2, 4096, 320] |      y       |      y       |      n       |                0.001
# 535 | Base | DONT CARE      | add attn2            |       [2, 4096, 320] |      y       |      y       |      n       |                0.011
# 536 | Base | DONT CARE      | norm3                |       [2, 4096, 320] |      y       |      y       |      n       |                0.015
# 537 | Base | DONT CARE      | ff                   |       [2, 4096, 320] |      y       |      y       |      n       |                0.012
# 538 | Base | DONT CARE      | add ff               |       [2, 4096, 320] |      y       |      y       |      n       |                0.016
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 539 | Base | DONT CARE      | proj_out             |     [2, 320, 64, 64] |      y       |      y       |      n       |                0.034
# ==============================================================================================================================================

# %%
c,l = cloud_cuda, local_cuda

# %%
### Base

c_inp_base,  l_inp_base  = c[7].t,  l[7].t   # input into 1st resnet (for base)
c_outp_base, l_outp_base = c[8].t,  l[8].t   # output of 1st resnet norm (for base)

for a,b in [
    (c_inp_base,  l_inp_base),
    (c_outp_base, l_outp_base),
]:
    print(a.shape, b.shape, mae(a, b))

print()

### Control

c_inp_ctrl,  l_inp_ctrl  = c[27].t, l[27].t  # input into 1st resnet (for ctrl)
c_outp_ctrl, l_outp_ctrl = c[28].t, l[28].t  # output of 1st resnet norm (for ctrl)

for a,b in [
    (c_inp_ctrl,  l_inp_ctrl), 
    (c_outp_ctrl, l_outp_ctrl)
]:
    print(a.shape, b.shape, mae(a, b))
# Out:
# torch.Size([2, 320, 64, 64]) torch.Size([2, 320, 64, 64]) tensor(0.002)
# torch.Size([2, 320, 64, 64]) torch.Size([2, 320, 64, 64]) tensor(0.002)
#
# torch.Size([2, 324, 64, 64]) torch.Size([2, 324, 64, 64]) tensor(0.010)
# torch.Size([2, 324, 64, 64]) torch.Size([2, 324, 64, 64]) tensor(0.011)

# %%
from torch import nn

assert 320%32==324%4==324%27==0

norm_base        = nn.GroupNorm(num_groups=32, num_channels=320)
norm_ctrl_is     = nn.GroupNorm(num_groups= 4, num_channels=324)
norm_ctrl_should = nn.GroupNorm(num_groups=27, num_channels=324)

# %%
# Should: base_norm(c_inp) == c_base_norm
mae(norm_base(c_inp_base), c_outp_base)
# Out:
# tensor(0.468, grad_fn=<MeanBackward0>)

# %%
# Should: base_norm(c_inp) == c_base_norm
mae(norm_base(l_inp_base), l_outp_base)
# Out:
# tensor(0.468, grad_fn=<MeanBackward0>)

# %% [markdown]
# GroupNorm saves statistics (mean, std) during training. The GroupNorms I created above are empty, and thus produce errors.
#
# Let's load the GroupNorms from Heidelberg-CNXS-SD21

# %%
# import scripts.control_utils as cu

# torch.use_deterministic_algorithms(True)

# path_to_config = 'cnxs_config/sd/sd21_encD_canny_14m.yaml'

# model = cu.create_model(path_to_config).to('cuda')

# norm_base = model.model.diffusion_model.input_blocks[1][0].in_layers[0].to('cpu')
# norm_base
# # > GroupNorm32(32, 320, eps=1e-05, affine=True)

# # # Should: base_norm(c_inp) == c_base_norm
# mae(norm_base(c_inp_base), c_outp_base)
# # > tensor(    0.000, grad_fn=<MeanBackward0>)

# # # Should: base_norm(c_inp) == c_base_norm
# mae(norm_base(l_inp_base), l_outp_base)
# # > tensor(    0.000, grad_fn=<MeanBackward0>)

# %% [markdown]
# I could reproduce the norm output for base (for cuda & local).

# %% [markdown]
# Let's now load the GroupNorms from Diffusers-CNXS-SD21

# %%
from diffusers import StableDiffusionPipeline
from diffusers import ControlNetXSModel
from diffusers import StableDiffusionControlNetXSPipeline

sd_pipe = StableDiffusionPipeline.from_single_file('weights/sd/sd21/v2-1_512-ema-pruned.ckpt')
cnxs = ControlNetXSModel.from_pretrained('weights/cnxs_diffusers/sd21-canny')

cnxs_pipe = StableDiffusionControlNetXSPipeline(
    vae=sd_pipe.vae,
    text_encoder=sd_pipe.text_encoder,
    tokenizer=sd_pipe.tokenizer,
    unet=sd_pipe.unet,
    controlnet=cnxs,
    scheduler=sd_pipe.scheduler,
    safety_checker=sd_pipe.safety_checker,
    feature_extractor=sd_pipe.feature_extractor
).to('cpu')
# Out:
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# /home/diffusers/src/diffusers/configuration_utils.py:135: FutureWarning: Accessing config attribute `requires_safety_checker` directly via 'StableDiffusionPipeline' object attribute is deprecated. Please access 'requires_safety_checker' over 'StableDiffusionPipeline's config object instead, e.g. 'scheduler.config.requires_safety_checker'.
#   deprecate("direct config name access", "1.0.0", deprecation_message, standard_warn=False)
# You have disabled the safety checker for <class 'diffusers.pipelines.controlnet_xs.pipeline_controlnet_xs.StableDiffusionControlNetXSPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
norm_ctrl = cnxs_pipe.controlnet.control_model.down_blocks[0].resnets[0].norm1.to('cpu')
norm_ctrl.num_groups = 4 # as currently is
norm_ctrl

# > GroupNorm(4, 324, eps=1e-05, affine=True)

# # Should: base_norm(c_inp) == c_base_norm
mae(norm_ctrl(l_inp_ctrl), l_outp_ctrl)
# > tensor(    0.000, grad_fn=<MeanBackward0>)
# # I can recreate the error exactly

norm_ctrl.num_groups = 27 # as should be
mae(norm_ctrl(l_inp_ctrl), l_outp_ctrl)
# > tensor(0.217, grad_fn=<MeanBackward0>)

norm_ctrl.num_groups = 27
# Should: base_cltr(c_inp) == c_ctrl_norm
mae(norm_ctrl(c_inp_ctrl), c_outp_ctrl)
# > tensor(    0.000, grad_fn=<MeanBackward0>)
# Out:
# tensor(    0.000, grad_fn=<MeanBackward0>)
