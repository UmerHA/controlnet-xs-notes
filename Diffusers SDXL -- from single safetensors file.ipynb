# %% [markdown]
# In this notebook, I load SDXL from the file `sd_xl_base_1.0_0.9vae.safetensors`

# %%
#!pip install -Uqq transformers diffusers

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps'
device_dtype = torch.float16 if device == 'cuda' else torch.float32

# %%
from diffusers import StableDiffusionXLPipeline

# %%
pipe = StableDiffusionXLPipeline.from_single_file('weights/sdxl/sd_xl_base_1.0_0.9vae.safetensors')

# %%
pipe = pipe.to(device)

# %%
prompt  = 'cinematic, shoe in the streets, made from meat, photorealistic shoe, highly detailed'
nprompt = 'lowres, bad anatomy, worst quality, low quality'
size = 8*(756//8)

# %%
im = pipe(prompt, width=size, height=size, negative_prompt=nprompt)[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
im[0]
# Out:
# <PIL.Image.Image image mode=RGB size=752x752>

# %%
im = pipe(prompt, width=size, height=size, negative_prompt=nprompt, num_inference_steps=10)[0]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
im[0]
# Out:
# <PIL.Image.Image image mode=RGB size=752x752>
