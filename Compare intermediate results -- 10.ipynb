# %% [markdown]
# Ok, with `control_scale *= 0`, I get the same results across local cuda and cloud cuda.
#
# Still, the application of control blocks produces errors. So let's zoom into that.

# %%
import torch
from torch.testing import assert_close
from torch import allclose, nn, tensor
torch.set_printoptions(linewidth=200, precision=3, sci_mode=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps'
device_dtype = torch.float16 if device == 'cuda' else torch.float32

# %% [markdown]
# ## Load logs

# %%
from diffusers.umer_debug_logger import UmerDebugLogger

# %%
cloud_cuda = UmerDebugLogger.load_log_objects_from_dir('logs/cloud')
local_cuda = UmerDebugLogger.load_log_objects_from_dir('logs/local_cuda')

# %%
len(cloud_cuda), len(local_cuda)
# Out:
# (970, 970)

# %%
for i, (c,l) in enumerate(zip(cloud_cuda, local_cuda)):
    if c.msg!=l.msg: print(f'{i:<3}{c.msg:>20}{l.msg:>20}')

# %% [markdown]
# ## Compare intermediate results

# %%
def mae(t1,t2):
    assert t1.shape==t2.shape
    return (t1-t2).abs().mean()

# %%
from functools import partial
from util_inspect import fmt_bool

def compare_intermediate_results(n=None,n_start=0,prec=5, compare_prec=3):
    if n is None: n=max(len(cloud_cuda), len(local_cuda))

    print(f'{"":<3} | {"block":<20} | {"name":<20} | {"shape":<20} | {"same names?":<12} | {"same shapes?":<12} | {"same values?":<12} | {"Δ cuda local -> cloud":<20}')
    print(f'{"":<3} | {"":<20} | {"":<20} | {"":<20} | {"":<12} | {"":<12} | {"prec="+str(compare_prec):^12} | {"prec="+str(prec):^20}')

    def calc_total_len(lens): return sum(lens)+3*len(lens)-1
    total_len = calc_total_len((3,20,20,20,12,12,12,20))

    line = partial(
        lambda txt, width: print(txt * (width//len(txt))),
        width=total_len
    )
    
    labels = []
    def add_label(lbs, ctrl=True):
        if not isinstance(lbs, (list, tuple)): lbs = [lbs]
        for l in lbs:
            labels.append(('Base',l))
        if ctrl:
            for l in lbs: 
                labels.append(('Ctrl',l))
    
    # # down
    # 1
    add_label('ResBlock 1.1')
    add_label('ResBlock 1.2')
    add_label('Conv 1')
    # 2
    add_label(('ResBlock 2.1', 'AttnBlock 2.1'))
    add_label(('ResBlock 2.2', 'AttnBlock 2.2'))
    add_label('Conv 2')
    # 3
    add_label(('ResBlock 3.1', 'AttnBlock 3.1'))
    add_label(('ResBlock 3.2', 'AttnBlock 3.2')) 
    # # mid
    add_label(('ResBlock', 'AttnBlock', 'ResBlock'))
    # # up
    for _ in range(1000): add_label('DONT CARE', ctrl=False)
    
    line('#')
    bc,block=labels.pop(0)
    for i in range(n_start,n):
        cc,lc = cloud_cuda[i], local_cuda[i]
                
        eq_name = cc.msg==lc.msg
        eq_shape = cc.shape==lc.shape
        eq_vals = torch.allclose(cc.t,lc.t,atol=10**-compare_prec)

        mae_2 = mae(lc.t,cc.t)        
        mae_2 = ("{:>20."+str(prec)+"f}").format(mae_2)
        
        print(f'{i+1:<3} | {bc:<4} | {block:<13} | {cc.msg:<20} | {cc.shape:>20} | {fmt_bool(eq_name, "^12")} | {fmt_bool(eq_shape, "^12")} | {fmt_bool(eq_vals, "^12")} | {mae_2}')
        
        if cc.msg in ('add conv_shortcut','conv','proj_out'):
            line('=')
            bc,block=labels.pop(0)
        elif cc.msg in ('add ff','proj_in'): line('- ')

# %%
compare_intermediate_results(compare_prec=3, prec=3)
# Out:
#     | block                | name                 | shape                | same names?  | same shapes? | same values? | Δ cuda local -> cloud
#     |                      |                      |                      |              |              |    prec=3    |        prec=3
# ##############################################################################################################################################
# 1   | Base | ResBlock 1.1  | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 2   | Base | ResBlock 1.1  | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 3   | Base | ResBlock 1.1  | conv2                |     [2, 320, 96, 96] |      y       |      y       |      y       |                0.000
# 4   | Base | ResBlock 1.1  | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 5   | Ctrl | ResBlock 1.1  | conv1                |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 6   | Ctrl | ResBlock 1.1  | add time_emb_proj    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 7   | Ctrl | ResBlock 1.1  | conv2                |      [2, 32, 96, 96] |      y       |      y       |      y       |                0.000
# 8   | Ctrl | ResBlock 1.1  | add conv_shortcut    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 9   | Base | ResBlock 1.2  | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 10  | Base | ResBlock 1.2  | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 11  | Base | ResBlock 1.2  | conv2                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 12  | Base | ResBlock 1.2  | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 13  | Ctrl | ResBlock 1.2  | conv1                |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 14  | Ctrl | ResBlock 1.2  | add time_emb_proj    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 15  | Ctrl | ResBlock 1.2  | conv2                |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 16  | Ctrl | ResBlock 1.2  | add conv_shortcut    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 17  | Base | Conv 1        | conv                 |     [2, 320, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 18  | Ctrl | Conv 1        | conv                 |      [2, 32, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 19  | Base | ResBlock 2.1  | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 20  | Base | ResBlock 2.1  | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 21  | Base | ResBlock 2.1  | conv2                |     [2, 640, 48, 48] |      y       |      y       |      y       |                0.000
# 22  | Base | ResBlock 2.1  | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 23  | Base | AttnBlock 2.1 | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 24  | Base | AttnBlock 2.1 | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 25  | Base | AttnBlock 2.1 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 26  | Base | AttnBlock 2.1 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 27  | Base | AttnBlock 2.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 28  | Base | AttnBlock 2.1 | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 29  | Base | AttnBlock 2.1 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 30  | Base | AttnBlock 2.1 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 31  | Base | AttnBlock 2.1 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 32  | Base | AttnBlock 2.1 | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 33  | Base | AttnBlock 2.1 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 34  | Base | AttnBlock 2.1 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 35  | Base | AttnBlock 2.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 36  | Base | AttnBlock 2.1 | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 37  | Base | AttnBlock 2.1 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 38  | Base | AttnBlock 2.1 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 39  | Base | AttnBlock 2.1 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 40  | Base | AttnBlock 2.1 | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 41  | Ctrl | ResBlock 2.1  | conv1                |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.000
# 42  | Ctrl | ResBlock 2.1  | add time_emb_proj    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.000
# 43  | Ctrl | ResBlock 2.1  | conv2                |      [2, 64, 48, 48] |      y       |      y       |      y       |                0.000
# 44  | Ctrl | ResBlock 2.1  | add conv_shortcut    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 45  | Ctrl | AttnBlock 2.1 | proj_in              |        [2, 2304, 64] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 46  | Ctrl | AttnBlock 2.1 | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.054
# 47  | Ctrl | AttnBlock 2.1 | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.054
# 48  | Ctrl | AttnBlock 2.1 | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.069
# 49  | Ctrl | AttnBlock 2.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 50  | Ctrl | AttnBlock 2.1 | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.627
# 51  | Ctrl | AttnBlock 2.1 | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                0.654
# 52  | Ctrl | AttnBlock 2.1 | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.037
# 53  | Ctrl | AttnBlock 2.1 | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                0.658
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 54  | Ctrl | AttnBlock 2.1 | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.053
# 55  | Ctrl | AttnBlock 2.1 | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.676
# 56  | Ctrl | AttnBlock 2.1 | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.170
# 57  | Ctrl | AttnBlock 2.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 58  | Ctrl | AttnBlock 2.1 | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.590
# 59  | Ctrl | AttnBlock 2.1 | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                1.051
# 60  | Ctrl | AttnBlock 2.1 | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.088
# 61  | Ctrl | AttnBlock 2.1 | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                1.063
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 62  | Ctrl | AttnBlock 2.1 | proj_out             |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.163
# ==============================================================================================================================================
# 63  | Base | ResBlock 2.2  | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 64  | Base | ResBlock 2.2  | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 65  | Base | ResBlock 2.2  | conv2                |     [2, 640, 48, 48] |      y       |      y       |      y       |                0.000
# 66  | Base | ResBlock 2.2  | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 67  | Base | AttnBlock 2.2 | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 68  | Base | AttnBlock 2.2 | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 69  | Base | AttnBlock 2.2 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 70  | Base | AttnBlock 2.2 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 71  | Base | AttnBlock 2.2 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 72  | Base | AttnBlock 2.2 | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 73  | Base | AttnBlock 2.2 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 74  | Base | AttnBlock 2.2 | ff                   |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 75  | Base | AttnBlock 2.2 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 76  | Base | AttnBlock 2.2 | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 77  | Base | AttnBlock 2.2 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 78  | Base | AttnBlock 2.2 | norm2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 79  | Base | AttnBlock 2.2 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 80  | Base | AttnBlock 2.2 | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 81  | Base | AttnBlock 2.2 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 82  | Base | AttnBlock 2.2 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 83  | Base | AttnBlock 2.2 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 84  | Base | AttnBlock 2.2 | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 85  | Ctrl | ResBlock 2.2  | conv1                |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.040
# 86  | Ctrl | ResBlock 2.2  | add time_emb_proj    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.040
# 87  | Ctrl | ResBlock 2.2  | conv2                |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.004
# 88  | Ctrl | ResBlock 2.2  | add conv_shortcut    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.063
# ==============================================================================================================================================
# 89  | Ctrl | AttnBlock 2.2 | proj_in              |        [2, 2304, 64] |      y       |      y       |      n       |                0.012
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 90  | Ctrl | AttnBlock 2.2 | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.026
# 91  | Ctrl | AttnBlock 2.2 | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# 92  | Ctrl | AttnBlock 2.2 | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.017
# 93  | Ctrl | AttnBlock 2.2 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 94  | Ctrl | AttnBlock 2.2 | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.001
# 95  | Ctrl | AttnBlock 2.2 | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# 96  | Ctrl | AttnBlock 2.2 | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.002
# 97  | Ctrl | AttnBlock 2.2 | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 98  | Ctrl | AttnBlock 2.2 | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.001
# 99  | Ctrl | AttnBlock 2.2 | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# 100 | Ctrl | AttnBlock 2.2 | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.004
# 101 | Ctrl | AttnBlock 2.2 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 102 | Ctrl | AttnBlock 2.2 | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.244
# 103 | Ctrl | AttnBlock 2.2 | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                0.246
# 104 | Ctrl | AttnBlock 2.2 | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.008
# 105 | Ctrl | AttnBlock 2.2 | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                0.247
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 106 | Ctrl | AttnBlock 2.2 | proj_out             |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.077
# ==============================================================================================================================================
# 107 | Base | Conv 2        | conv                 |     [2, 640, 24, 24] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 108 | Ctrl | Conv 2        | conv                 |      [2, 64, 24, 24] |      y       |      y       |      n       |                0.083
# ==============================================================================================================================================
# 109 | Base | ResBlock 3.1  | conv1                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 110 | Base | ResBlock 3.1  | add time_emb_proj    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 111 | Base | ResBlock 3.1  | conv2                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 112 | Base | ResBlock 3.1  | add conv_shortcut    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 113 | Base | AttnBlock 3.1 | proj_in              |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 114 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 115 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 116 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 117 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 118 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 119 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 120 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 121 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 122 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 123 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 124 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 125 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 126 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 127 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 128 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 129 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 130 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 131 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 132 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 133 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 134 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 135 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 136 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 137 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 138 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 139 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 140 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 141 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 142 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 143 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 144 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 145 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 146 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 147 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 148 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 149 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 150 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 151 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 152 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 153 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 154 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 155 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 156 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 157 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 158 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 159 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 160 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 161 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 162 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 163 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 164 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 165 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 166 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 167 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 168 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 169 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 170 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 171 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 172 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 173 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 174 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 175 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 176 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 177 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 178 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 179 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 180 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 181 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 182 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 183 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 184 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 185 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 186 | Base | AttnBlock 3.1 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 187 | Base | AttnBlock 3.1 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 188 | Base | AttnBlock 3.1 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 189 | Base | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 190 | Base | AttnBlock 3.1 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 191 | Base | AttnBlock 3.1 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 192 | Base | AttnBlock 3.1 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 193 | Base | AttnBlock 3.1 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 194 | Base | AttnBlock 3.1 | proj_out             |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 195 | Ctrl | ResBlock 3.1  | conv1                |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.009
# 196 | Ctrl | ResBlock 3.1  | add time_emb_proj    |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.009
# 197 | Ctrl | ResBlock 3.1  | conv2                |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.001
# 198 | Ctrl | ResBlock 3.1  | add conv_shortcut    |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.023
# ==============================================================================================================================================
# 199 | Ctrl | AttnBlock 3.1 | proj_in              |        [2, 576, 128] |      y       |      y       |      n       |                0.005
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 200 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.194
# 201 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                0.194
# 202 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.059
# 203 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 204 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.585
# 205 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                0.663
# 206 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.022
# 207 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                0.663
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 208 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.521
# 209 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                0.945
# 210 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.118
# 211 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 212 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                1.720
# 213 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                2.248
# 214 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.017
# 215 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                2.247
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 216 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.340
# 217 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                2.418
# 218 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.104
# 219 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 220 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                2.056
# 221 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                3.779
# 222 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.019
# 223 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                3.781
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 224 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.101
# 225 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                3.759
# 226 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.103
# 227 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 228 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.161
# 229 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                3.767
# 230 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.015
# 231 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                3.767
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 232 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.213
# 233 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                3.712
# 234 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.102
# 235 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 236 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.374
# 237 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                3.762
# 238 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.021
# 239 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                3.763
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 240 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.098
# 241 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                3.770
# 242 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.099
# 243 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 244 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                1.752
# 245 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.156
# 246 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.032
# 247 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.161
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 248 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.049
# 249 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.155
# 250 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.119
# 251 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 252 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.145
# 253 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.144
# 254 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.038
# 255 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.137
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 256 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.040
# 257 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.128
# 258 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.115
# 259 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 260 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                2.190
# 261 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.277
# 262 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.044
# 263 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.267
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 264 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.034
# 265 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.266
# 266 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.124
# 267 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 268 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.208
# 269 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.277
# 270 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.043
# 271 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.268
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 272 | Ctrl | AttnBlock 3.1 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.028
# 273 | Ctrl | AttnBlock 3.1 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.267
# 274 | Ctrl | AttnBlock 3.1 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.124
# 275 | Ctrl | AttnBlock 3.1 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 276 | Ctrl | AttnBlock 3.1 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                2.380
# 277 | Ctrl | AttnBlock 3.1 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                5.235
# 278 | Ctrl | AttnBlock 3.1 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.057
# 279 | Ctrl | AttnBlock 3.1 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                5.222
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 280 | Ctrl | AttnBlock 3.1 | proj_out             |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.858
# ==============================================================================================================================================
# 281 | Base | ResBlock 3.2  | conv1                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 282 | Base | ResBlock 3.2  | add time_emb_proj    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# ...
# 881 | Base | DONT CARE     | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 882 | Base | DONT CARE     | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 883 | Base | DONT CARE     | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 884 | Base | DONT CARE     | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 885 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 886 | Base | DONT CARE     | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 887 | Base | DONT CARE     | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 888 | Base | DONT CARE     | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 889 | Base | DONT CARE     | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 890 | Base | DONT CARE     | proj_out             |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.001
# ==============================================================================================================================================
# 891 | Base | DONT CARE     | conv                 |    [2, 1280, 48, 48] |      y       |      y       |      n       |                0.002
# ==============================================================================================================================================
# 892 | Base | DONT CARE     | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# 893 | Base | DONT CARE     | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# 894 | Base | DONT CARE     | conv2                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 895 | Base | DONT CARE     | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# ==============================================================================================================================================
# 896 | Base | DONT CARE     | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 897 | Base | DONT CARE     | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 898 | Base | DONT CARE     | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 899 | Base | DONT CARE     | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 900 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 901 | Base | DONT CARE     | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 902 | Base | DONT CARE     | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 903 | Base | DONT CARE     | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 904 | Base | DONT CARE     | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 905 | Base | DONT CARE     | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 906 | Base | DONT CARE     | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 907 | Base | DONT CARE     | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 908 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 909 | Base | DONT CARE     | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 910 | Base | DONT CARE     | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 911 | Base | DONT CARE     | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 912 | Base | DONT CARE     | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 913 | Base | DONT CARE     | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# ==============================================================================================================================================
# 914 | Base | DONT CARE     | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 915 | Base | DONT CARE     | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 916 | Base | DONT CARE     | conv2                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 917 | Base | DONT CARE     | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 918 | Base | DONT CARE     | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 919 | Base | DONT CARE     | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 920 | Base | DONT CARE     | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 921 | Base | DONT CARE     | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 922 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 923 | Base | DONT CARE     | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 924 | Base | DONT CARE     | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 925 | Base | DONT CARE     | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 926 | Base | DONT CARE     | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 927 | Base | DONT CARE     | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 928 | Base | DONT CARE     | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 929 | Base | DONT CARE     | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 930 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 931 | Base | DONT CARE     | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 932 | Base | DONT CARE     | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 933 | Base | DONT CARE     | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 934 | Base | DONT CARE     | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 935 | Base | DONT CARE     | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 936 | Base | DONT CARE     | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 937 | Base | DONT CARE     | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 938 | Base | DONT CARE     | conv2                |     [2, 640, 48, 48] |      y       |      y       |      y       |                0.000
# 939 | Base | DONT CARE     | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 940 | Base | DONT CARE     | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 941 | Base | DONT CARE     | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 942 | Base | DONT CARE     | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 943 | Base | DONT CARE     | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 944 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 945 | Base | DONT CARE     | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 946 | Base | DONT CARE     | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 947 | Base | DONT CARE     | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 948 | Base | DONT CARE     | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 949 | Base | DONT CARE     | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 950 | Base | DONT CARE     | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 951 | Base | DONT CARE     | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 952 | Base | DONT CARE     | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 953 | Base | DONT CARE     | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 954 | Base | DONT CARE     | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 955 | Base | DONT CARE     | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 956 | Base | DONT CARE     | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 957 | Base | DONT CARE     | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 958 | Base | DONT CARE     | conv                 |     [2, 640, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 959 | Base | DONT CARE     | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 960 | Base | DONT CARE     | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 961 | Base | DONT CARE     | conv2                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 962 | Base | DONT CARE     | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 963 | Base | DONT CARE     | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 964 | Base | DONT CARE     | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 965 | Base | DONT CARE     | conv2                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 966 | Base | DONT CARE     | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================
# 967 | Base | DONT CARE     | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 968 | Base | DONT CARE     | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 969 | Base | DONT CARE     | conv2                |     [2, 320, 96, 96] |      y       |      y       |      y       |                0.000
# 970 | Base | DONT CARE     | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# ==============================================================================================================================================

# %% [markdown]
# The errors arise in the transformer-parts of each control block.<br/>
# The first error arises in step 46.
#
# So let's manually run through that transformer, for local and cloud.

# %%
inp_c = cloud_cuda[46-1].t
inp_l = local_cuda[46-1].t

# %%
del cloud_cuda, local_cuda

# %%
inp_c.shape, inp_l.shape
# Out:
# (torch.Size([2, 2304, 64]), torch.Size([2, 2304, 64]))

# %% [markdown]
# Load diffusers version, but keep in on cpu, so we can load Heidelberg version into gpu

# %%
from diffusers import StableDiffusionXLPipeline
from diffusers import EulerDiscreteScheduler
from diffusers.models.controlnetxs import ControlNetXSModel
from diffusers.pipelines.controlnet_xs.pipeline_controlnet_xs_sd_xl import StableDiffusionXLControlNetXSPipeline

sdxl_pipe = StableDiffusionXLPipeline.from_single_file('weights/sd_xl_base_1.0_0.9vae.safetensors', device='cpu')
cnxs = ControlNetXSModel.from_pretrained('weights/cnxs', device='cpu')

cnxs.base_model = sdxl_pipe.unet

cnxs.scale_list = cnxs.scale_list * 0. + 0.95
assert cnxs.scale_list[0] == .95

scheduler_cgf = dict(sdxl_pipe.scheduler.config)
scheduler_cgf['timestep_spacing'] = 'linspace'
sdxl_pipe.scheduler = EulerDiscreteScheduler.from_config(scheduler_cgf)

# test it worked
sdxl_pipe.scheduler.set_timesteps(50)
assert sdxl_pipe.scheduler.timesteps[0]==999

# reset
sdxl_pipe.scheduler = EulerDiscreteScheduler.from_config(scheduler_cgf)

cnxs_pipe = StableDiffusionXLControlNetXSPipeline(
    vae=sdxl_pipe.vae,
    text_encoder=sdxl_pipe.text_encoder,
    text_encoder_2=sdxl_pipe.text_encoder_2,
    tokenizer=sdxl_pipe.tokenizer,
    tokenizer_2=sdxl_pipe.tokenizer_2,
    unet=sdxl_pipe.unet,
    controlnet=cnxs,
    scheduler=sdxl_pipe.scheduler,
)
# Out:
# sigmas after (linear) interpolation: [14.61464691 12.93677721 11.49164976 10.24291444  9.16035419] ...

# %% [markdown]
# Load Heidelberg version

# %%
import scripts.control_utils as cu
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Downloading: "https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/dpt_hybrid-midas-501f0c75.pt" to /home/ControlNet-XS/annotator/ckpts/dpt_hybrid-midas-501f0c75.pt
# 100%|██████████| 470M/470M [00:04<00:00, 120MB/s]
# /opt/conda/lib/python3.10/site-packages/timm/models/_factory.py:114: UserWarning: Mapping deprecated model name vit_base_resnet50_384 to current vit_base_r50_s16_384.orig_in21k_ft_in1k.
#   model = create_fn(

# %%
path_to_config = 'cnxs_config/sdxl/sdxl_encD_canny_48m.yaml'

# %% [markdown]
# If this results in the kernel crashing, I'm using too much GPU memory elsewhere. Shut down every other kernel and try again.

# %%
model = cu.create_model(path_to_config).to('cuda')
# Out:
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 320, out-chn: 320, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 640, out-chn: 640, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 352, out-chn: 32, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 2 w/ 64 channels and 1 heads
# constructing SpatialTransformer of depth 2 w/ 64 channels and 1 heads
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 704, out-chn: 64, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 10 w/ 128 channels and 2 heads
# constructing SpatialTransformer of depth 10 w/ 128 channels and 2 heads
# constructing SpatialTransformer of depth 10 w/ 128 channels and 2 heads
# Initialized embedder #0: FrozenCLIPEmbedder with 123060480 params. Trainable: False

# %% [markdown]
# **Okay, the kernel crashes, presumibly due to cpu memory error.** So let's do the comparison on 2 computers (instead of running both models on this one). See `Run Heidelnerg ctrl attention.ipynb` and `Run diffusers ctrl attetntion.ipynb`.
