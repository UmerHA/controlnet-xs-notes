# %% [markdown]
# Ok, with `control_scale *= 0`, I get the same results across local cuda and cloud cuda.
#
# Still, the application of control blocks produces errors. So let's zoom into that.

# %%
import torch
from torch.testing import assert_close
from torch import allclose, nn, tensor
torch.set_printoptions(linewidth=200, precision=3, sci_mode=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps'
device_dtype = torch.float16 if device == 'cuda' else torch.float32

# %% [markdown]
# ## Load logs

# %%
from diffusers.umer_debug_logger import UmerDebugLogger

# %%
cloud_cuda = UmerDebugLogger.load_log_objects_from_dir('logs/cloud')
local_cuda = UmerDebugLogger.load_log_objects_from_dir('logs/local_cuda')

# %%
len(cloud_cuda), len(local_cuda)
# Out:
# (970, 970)

# %%
for i, (c,l) in enumerate(zip(cloud_cuda, local_cuda)):
    if c.msg!=l.msg: print(f'{i:<3}{c.msg:>20}{l.msg:>20}')

# %% [markdown]
# ## Compare intermediate results

# %%
def mae(t1,t2):
    assert t1.shape==t2.shape
    return (t1-t2).abs().mean()

# %%
from functools import partial
from util_inspect import fmt_bool

def compare_intermediate_results(n=None,n_start=0,prec=5, compare_prec=3, skip_ctrl=False):
    if n is None: n=max(len(cloud_cuda), len(local_cuda))

    print(f'{"":<3} | {"name":<20} | {"shape":<20} | {"same names?":<12} | {"same shapes?":<12} | {"same values?":<12} | {"Δ cuda local -> cloud":<20}')
    print(f'{"":<3} | {"":<20} | {"":<20} | {"":<12} | {"":<12} | {"prec="+str(compare_prec):^12} | {"prec="+str(prec):^20}')

    def calc_total_len(lens): return sum(lens)+3*len(lens)-1
    total_len = calc_total_len((3,20,20,12,12,12,20))

    line = partial(
        lambda txt, width: print(txt * (width//len(txt))),
        width=total_len
    )
    
                                                                                          # output     
    line('#')
    lv,block=1,1
    for i in range(n_start,n):
        cc,lc = cloud_cuda[i], local_cuda[i]
                
        eq_name = cc.msg==lc.msg
        eq_shape = cc.shape==lc.shape
        eq_vals = torch.allclose(cc.t,lc.t,atol=10**-compare_prec)

        mae_2 = mae(lc.t,cc.t)        
        mae_2 = ("{:>20."+str(prec)+"f}").format(mae_2)
        
        if not skip_ctrl or not 'ctrl' in cc.msg:
            print(f'{i+1:<3} | {cc.msg:<20} | {cc.shape:>20} | {fmt_bool(eq_name, "^12")} | {fmt_bool(eq_shape, "^12")} | {fmt_bool(eq_vals, "^12")} | {mae_2}')
        
        if cc.msg in ('add conv_shortcut','conv','proj_out'): line('=')
        elif cc.msg in ('add ff','proj_in'): line('- ')

# %%
compare_intermediate_results(compare_prec=3, prec=3, skip_ctrl=True)
# Out:
#     | name                 | shape                | same names?  | same shapes? | same values? | Δ cuda local -> cloud
#     |                      |                      |              |              |    prec=3    |        prec=3
# #######################################################################################################################
# 1   | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 2   | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 3   | conv2                |     [2, 320, 96, 96] |      y       |      y       |      y       |                0.000
# 4   | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 5   | conv1                |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 6   | add time_emb_proj    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 7   | conv2                |      [2, 32, 96, 96] |      y       |      y       |      y       |                0.000
# 8   | add conv_shortcut    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 9   | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 10  | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 11  | conv2                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 12  | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 13  | conv1                |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 14  | add time_emb_proj    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 15  | conv2                |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# 16  | add conv_shortcut    |      [2, 32, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 17  | conv                 |     [2, 320, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 18  | conv                 |      [2, 32, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 19  | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 20  | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 21  | conv2                |     [2, 640, 48, 48] |      y       |      y       |      y       |                0.000
# 22  | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 23  | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 24  | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 25  | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 26  | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 27  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 28  | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 29  | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 30  | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 31  | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 32  | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 33  | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 34  | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 35  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 36  | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 37  | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 38  | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 39  | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 40  | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 41  | conv1                |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.000
# 42  | add time_emb_proj    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.000
# 43  | conv2                |      [2, 64, 48, 48] |      y       |      y       |      y       |                0.000
# 44  | add conv_shortcut    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 45  | proj_in              |        [2, 2304, 64] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 46  | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.054
# 47  | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.054
# 48  | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.069
# 49  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 50  | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.627
# 51  | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                0.654
# 52  | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.037
# 53  | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                0.658
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 54  | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.053
# 55  | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.676
# 56  | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.170
# 57  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 58  | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.590
# 59  | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                1.051
# 60  | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.088
# 61  | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                1.063
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 62  | proj_out             |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.163
# =======================================================================================================================
# 63  | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 64  | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 65  | conv2                |     [2, 640, 48, 48] |      y       |      y       |      y       |                0.000
# 66  | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 67  | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 68  | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 69  | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 70  | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 71  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 72  | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 73  | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 74  | ff                   |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 75  | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 76  | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 77  | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 78  | norm2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 79  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 80  | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 81  | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 82  | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 83  | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 84  | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 85  | conv1                |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.040
# 86  | add time_emb_proj    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.040
# 87  | conv2                |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.004
# 88  | add conv_shortcut    |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.063
# =======================================================================================================================
# 89  | proj_in              |        [2, 2304, 64] |      y       |      y       |      n       |                0.012
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 90  | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.026
# 91  | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# 92  | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.017
# 93  | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 94  | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.001
# 95  | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# 96  | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.002
# 97  | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 98  | attn1                |        [2, 2304, 64] |      y       |      y       |      n       |                0.001
# 99  | add attn1            |        [2, 2304, 64] |      y       |      y       |      n       |                0.031
# 100 | norm2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.004
# 101 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 102 | attn2                |        [2, 2304, 64] |      y       |      y       |      n       |                0.244
# 103 | add attn2            |        [2, 2304, 64] |      y       |      y       |      n       |                0.246
# 104 | ff                   |        [2, 2304, 64] |      y       |      y       |      n       |                0.008
# 105 | add ff               |        [2, 2304, 64] |      y       |      y       |      n       |                0.247
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 106 | proj_out             |      [2, 64, 48, 48] |      y       |      y       |      n       |                0.077
# =======================================================================================================================
# 107 | conv                 |     [2, 640, 24, 24] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 108 | conv                 |      [2, 64, 24, 24] |      y       |      y       |      n       |                0.083
# =======================================================================================================================
# 109 | conv1                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 110 | add time_emb_proj    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 111 | conv2                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 112 | add conv_shortcut    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 113 | proj_in              |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 114 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 115 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 116 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 117 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 118 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 119 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 120 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 121 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 122 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 123 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 124 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 125 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 126 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 127 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 128 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 129 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 130 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 131 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 132 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 133 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 134 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 135 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 136 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 137 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 138 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 139 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 140 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 141 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 142 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 143 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 144 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 145 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 146 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 147 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 148 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 149 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 150 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 151 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 152 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 153 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 154 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 155 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 156 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 157 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 158 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 159 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 160 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 161 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 162 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 163 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 164 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 165 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 166 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 167 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 168 | ff                   |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 169 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 170 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 171 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 172 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 173 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 174 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 175 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 176 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 177 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 178 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 179 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 180 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 181 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 182 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 183 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 184 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 185 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 186 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 187 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 188 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 189 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 190 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 191 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 192 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 193 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 194 | proj_out             |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 195 | conv1                |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.009
# 196 | add time_emb_proj    |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.009
# 197 | conv2                |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.001
# 198 | add conv_shortcut    |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.023
# =======================================================================================================================
# 199 | proj_in              |        [2, 576, 128] |      y       |      y       |      n       |                0.005
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 200 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.194
# 201 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                0.194
# 202 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.059
# 203 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 204 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.585
# 205 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                0.663
# 206 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.022
# 207 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                0.663
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 208 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.521
# 209 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                0.945
# 210 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.118
# 211 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 212 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                1.720
# 213 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                2.248
# 214 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.017
# 215 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                2.247
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 216 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.340
# 217 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                2.418
# 218 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.104
# 219 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 220 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                2.056
# 221 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                3.779
# 222 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.019
# 223 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                3.781
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 224 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.101
# 225 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                3.759
# 226 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.103
# 227 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 228 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.161
# 229 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                3.767
# 230 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.015
# 231 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                3.767
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 232 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.213
# 233 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                3.712
# 234 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.102
# 235 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 236 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.374
# 237 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                3.762
# 238 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.021
# 239 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                3.763
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 240 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.098
# 241 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                3.770
# 242 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.099
# 243 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 244 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                1.752
# 245 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.156
# 246 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.032
# 247 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.161
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 248 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.049
# 249 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.155
# 250 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.119
# 251 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 252 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.145
# 253 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.144
# 254 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.038
# 255 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.137
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 256 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.040
# 257 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.128
# 258 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.115
# 259 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 260 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                2.190
# 261 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.277
# 262 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.044
# 263 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.267
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 264 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.034
# 265 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.266
# 266 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.124
# 267 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 268 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                0.208
# 269 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                4.277
# 270 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.043
# 271 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                4.268
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 272 | attn1                |        [2, 576, 128] |      y       |      y       |      n       |                0.028
# 273 | add attn1            |        [2, 576, 128] |      y       |      y       |      n       |                4.267
# 274 | norm2                |        [2, 576, 128] |      y       |      y       |      n       |                0.124
# 275 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 276 | attn2                |        [2, 576, 128] |      y       |      y       |      n       |                2.380
# 277 | add attn2            |        [2, 576, 128] |      y       |      y       |      n       |                5.235
# 278 | ff                   |        [2, 576, 128] |      y       |      y       |      n       |                0.057
# 279 | add ff               |        [2, 576, 128] |      y       |      y       |      n       |                5.222
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 280 | proj_out             |     [2, 128, 24, 24] |      y       |      y       |      n       |                0.858
# =======================================================================================================================
# 281 | conv1                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 282 | add time_emb_proj    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 283 | conv2                |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.000
# 284 | add conv_shortcut    |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.001
# =======================================================================================================================
# 285 | proj_in              |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 286 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 287 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 288 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 289 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 290 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 291 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 292 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 293 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 294 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 295 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 296 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 297 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 298 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 299 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 300 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 301 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 302 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 303 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 304 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 305 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 306 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 307 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 308 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 309 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 310 | attn1                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 311 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 312 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 313 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 314 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 315 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 316 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 317 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 318 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 319 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 320 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 321 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 322 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 323 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 324 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 325 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 326 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 327 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 328 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 329 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 330 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 331 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 332 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 333 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 334 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 335 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 336 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 337 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 338 | attn2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 339 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 340 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 341 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# ...
# 861 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 862 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 863 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 864 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 865 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 866 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 867 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 868 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 869 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 870 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 871 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 872 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 873 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 874 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 875 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 876 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 877 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 878 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 879 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 880 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 881 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 882 | attn1                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 883 | add attn1            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 884 | norm2                |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 885 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 886 | attn2                |       [2, 576, 1280] |      y       |      y       |      y       |                0.000
# 887 | add attn2            |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# 888 | ff                   |       [2, 576, 1280] |      y       |      y       |      n       |                0.000
# 889 | add ff               |       [2, 576, 1280] |      y       |      y       |      n       |                0.001
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 890 | proj_out             |    [2, 1280, 24, 24] |      y       |      y       |      n       |                0.001
# =======================================================================================================================
# 891 | conv                 |    [2, 1280, 48, 48] |      y       |      y       |      n       |                0.002
# =======================================================================================================================
# 892 | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# 893 | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# 894 | conv2                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 895 | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# =======================================================================================================================
# 896 | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 897 | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 898 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 899 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 900 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 901 | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 902 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 903 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 904 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 905 | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 906 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 907 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 908 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 909 | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 910 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 911 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 912 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 913 | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.001
# =======================================================================================================================
# 914 | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 915 | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 916 | conv2                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 917 | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 918 | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 919 | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 920 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 921 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 922 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 923 | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 924 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 925 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 926 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 927 | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 928 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 929 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 930 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 931 | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 932 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 933 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 934 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 935 | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 936 | conv1                |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 937 | add time_emb_proj    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# 938 | conv2                |     [2, 640, 48, 48] |      y       |      y       |      y       |                0.000
# 939 | add conv_shortcut    |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 940 | proj_in              |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 941 | attn1                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 942 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 943 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 944 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 945 | attn2                |       [2, 2304, 640] |      y       |      y       |      y       |                0.000
# 946 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 947 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 948 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 949 | attn1                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 950 | add attn1            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 951 | norm2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 952 | context              |        [2, 77, 2048] |      y       |      y       |      n       |                0.001
# 953 | attn2                |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 954 | add attn2            |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 955 | ff                   |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# 956 | add ff               |       [2, 2304, 640] |      y       |      y       |      n       |                0.000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 957 | proj_out             |     [2, 640, 48, 48] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 958 | conv                 |     [2, 640, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 959 | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 960 | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 961 | conv2                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 962 | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 963 | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 964 | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 965 | conv2                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 966 | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================
# 967 | conv1                |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 968 | add time_emb_proj    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# 969 | conv2                |     [2, 320, 96, 96] |      y       |      y       |      y       |                0.000
# 970 | add conv_shortcut    |     [2, 320, 96, 96] |      y       |      y       |      n       |                0.000
# =======================================================================================================================

# %% [markdown]
# The errors arise in the transformer-parts of each control block.<br/>
# The first error arises in step 46.
#
# So let's manually run through that transformer, for local and cloud.

# %%
inp_c = cloud_cuda[46-1].t
inp_l = local_cuda[46-1].t

# %%
del cloud_cuda, local_cuda

# %%
inp_c.shape, inp_l.shape
# Out:
# (torch.Size([2, 2304, 64]), torch.Size([2, 2304, 64]))

# %% [markdown]
# Load diffusers version, but keep in on cpu, so we can load Heidelberg version into gpu

# %%
from diffusers import StableDiffusionXLPipeline
from diffusers import EulerDiscreteScheduler
from diffusers.models.controlnetxs import ControlNetXSModel
from diffusers.pipelines.controlnet_xs.pipeline_controlnet_xs_sd_xl import StableDiffusionXLControlNetXSPipeline

sdxl_pipe = StableDiffusionXLPipeline.from_single_file('weights/sd_xl_base_1.0_0.9vae.safetensors', device='cpu')
cnxs = ControlNetXSModel.from_pretrained('weights/cnxs', device='cpu')

cnxs.base_model = sdxl_pipe.unet

cnxs.scale_list = cnxs.scale_list * 0. + 0.95
assert cnxs.scale_list[0] == .95

scheduler_cgf = dict(sdxl_pipe.scheduler.config)
scheduler_cgf['timestep_spacing'] = 'linspace'
sdxl_pipe.scheduler = EulerDiscreteScheduler.from_config(scheduler_cgf)

# test it worked
sdxl_pipe.scheduler.set_timesteps(50)
assert sdxl_pipe.scheduler.timesteps[0]==999

# reset
sdxl_pipe.scheduler = EulerDiscreteScheduler.from_config(scheduler_cgf)

cnxs_pipe = StableDiffusionXLControlNetXSPipeline(
    vae=sdxl_pipe.vae,
    text_encoder=sdxl_pipe.text_encoder,
    text_encoder_2=sdxl_pipe.text_encoder_2,
    tokenizer=sdxl_pipe.tokenizer,
    tokenizer_2=sdxl_pipe.tokenizer_2,
    unet=sdxl_pipe.unet,
    controlnet=cnxs,
    scheduler=sdxl_pipe.scheduler,
)
# Out:
# sigmas after (linear) interpolation: [14.61464691 12.93677721 11.49164976 10.24291444  9.16035419] ...

# %% [markdown]
# Load Heidelberg version

# %%
import scripts.control_utils as cu
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Downloading: "https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/dpt_hybrid-midas-501f0c75.pt" to /home/ControlNet-XS/annotator/ckpts/dpt_hybrid-midas-501f0c75.pt
# 100%|██████████| 470M/470M [00:04<00:00, 120MB/s]
# /opt/conda/lib/python3.10/site-packages/timm/models/_factory.py:114: UserWarning: Mapping deprecated model name vit_base_resnet50_384 to current vit_base_r50_s16_384.orig_in21k_ft_in1k.
#   model = create_fn(

# %%
path_to_config = 'cnxs_config/sdxl/sdxl_encD_canny_48m.yaml'

# %% [markdown]
# If this results in the kernel crashing, I'm using too much GPU memory elsewhere. Shut down every other kernel and try again.

# %%
model = cu.create_model(path_to_config).to('cuda')
# Out:
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 320, out-chn: 320, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 640, out-chn: 640, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 10 w/ 1280 channels and 20 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# constructing SpatialTransformer of depth 2 w/ 640 channels and 10 heads
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 352, out-chn: 32, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 2 w/ 64 channels and 1 heads
# constructing SpatialTransformer of depth 2 w/ 64 channels and 1 heads
# Building a Downsample layer with 2 dims.
#   --> settings are:
#  in-chn: 704, out-chn: 64, kernel-size: 3, stride: 2, padding: 1
# constructing SpatialTransformer of depth 10 w/ 128 channels and 2 heads
# constructing SpatialTransformer of depth 10 w/ 128 channels and 2 heads
# constructing SpatialTransformer of depth 10 w/ 128 channels and 2 heads
# Initialized embedder #0: FrozenCLIPEmbedder with 123060480 params. Trainable: False

# %% [markdown]
# **Okay, the kernel crashes, presumibly due to cpu memory error.** So let's do the comparison on 2 computers (instead of running both models on this one). See `Run Heidelnerg ctrl attention.ipynb` and `Run diffusers ctrl attetntion.ipynb`.
